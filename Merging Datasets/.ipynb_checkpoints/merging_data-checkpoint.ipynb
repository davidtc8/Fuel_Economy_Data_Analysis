# %% [markdown]
# # Merging Datasets
# Use pandas Merges to create a combined dataset from `clean_08.csv` and `clean_18.csv`. You should've created these data files in the previous section: *Fixing Data Types Pt 3*.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# load datasets
df_08 = pd.read_csv(r'C:\Users\David Torres\Desktop\Programming\Python\Data Analyst Udacity\Data Analysis Process-Case Study 2/clean_08.csv')
df_18 = pd.read_csv(r'C:\Users\David Torres\Desktop\Programming\Python\Data Analyst Udacity\Data Analysis Process-Case Study 2/clean_18.csv')
df_08.head(2)
# Out:
#        model  displ  cyl    trans drive      fuel veh_class  \
# 0  ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline       SUV
# 1  ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline       SUV
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score  \
# 0                  7.0      15.0     20.0     17.0                     4
# 1                  7.0      17.0     22.0     19.0                     5
#
#   smartway
# 0       no
# 1       no

# %% [markdown]
# ### Create combined dataset

# %%
# rename 2008 columns
df_08.rename(columns={"model": "model_2008", 
                      "displ": "displ_2008", "displ": "displ_2008", "displ": "displ_2008", "displ": "displ_2008"})
# Out:
#              model_2008  displ_2008  cyl    trans drive      fuel  \
# 0             ACURA MDX         3.7    6  Auto-S5   4WD  Gasoline
# 1             ACURA RDX         2.3    4  Auto-S5   4WD  Gasoline
# 2              ACURA RL         3.5    6  Auto-S5   4WD  Gasoline
# 3              ACURA TL         3.2    6  Auto-S5   2WD  Gasoline
# 4              ACURA TL         3.5    6  Auto-S5   2WD  Gasoline
# ..                  ...         ...  ...      ...   ...       ...
# 982         VOLVO XC 90         3.2    6  Auto-S6   2WD  Gasoline
# 983         VOLVO XC 90         3.2    6  Auto-S6   4WD  Gasoline
# 984         VOLVO XC 90         4.4    8  Auto-S6   4WD  Gasoline
# 985  MERCEDES-BENZ C300         3.0    6  Auto-L7   2WD   ethanol
# 986  MERCEDES-BENZ C300         3.0    6  Auto-L7   2WD       gas
#
#        veh_class  air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  \
# 0            SUV                  7.0      15.0     20.0     17.0
# ...

# %%
# view to check names
df_08.head()

# %%
# merge datasets
df_combined =

# %%
# view to check merge
df_combined.head()

# %% [markdown]
# Save the combined dataset

# %%
df_combined.to_csv('combined_dataset.csv', index=False)
